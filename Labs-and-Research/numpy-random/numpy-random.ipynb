# %% [markdown]
# # The Numpy Random Package
#
# [Official Documentation](https://numpy.org/doc/stable/reference/random/index.html)
#
# ***

# %%
# Efficient numerical arrays.
import numpy as np
# Plotting
import matplotlib.pyplot as plt

# %%
# Change default style sheet.
plt.style.use('fivethirtyeight')

# Change the default figure size
plt.rcParams['figure.figsize'] = [10, 5]

# %% [markdown]
# <br>
#
# ## numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# Look at the first ten items.
s[:10]
# Out:
# array([-0.07825604,  0.14942009,  0.06329065, -0.03546706,  0.06908899,
#        -0.01760062, -0.03071623, -0.0179317 , -0.003443  , -0.05043012])

# %%
abs(mu - np.mean(s))
# Out:
# 0.0005802791239904325

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.0010680230736150598

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f = 1/(sigma * np.sqrt(2*np.pi)) * np.exp( - (bins - mu)**2/(2*sigma**2) )
plt.plot(bins, f ,linewidth=2)
plt.show()

# %% [markdown]
# ## References
#
# 1. How to make inline plots in Jupyter Notebook larger. https://stackoverflow.com/questions/36367986/how-to-make-inline-plots-in-jupyter-notebook-larger
#
# 2. Customizing plots in Jupyter Notebook. https://matplotlib.org/stable/tutorials/introductory/customizing.html
#
# 3. Numpy-random tutorial by [DataCamp team](https://www.datacamp.com/profile/community-299a879d-d623-4b74-a507-5b63b0a4b1b0). https://www.datacamp.com/community/tutorials/numpy-random

# %% [markdown]
# ***
#
# ## End
